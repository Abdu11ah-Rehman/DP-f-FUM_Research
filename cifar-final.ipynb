# %%
# ============================================================
# CELL 0 — CONFIG
# Set DATASET to "CIFAR10", "MNIST", or "FashionMNIST"
# ============================================================
DATASET        = "CIFAR10"   # "MNIST" | "FashionMNIST" | "CIFAR10"
METHOD         = "ffum"      # "ffum" | "ffum_median"
SEED           = 17          # then re-run with 42 and 123
SIGMA_SWEEP    = True        # True → runs σ ∈ {0, 0.5, 1, 2, 4} in one go
SIGMA          = 0.0         # only used if SIGMA_SWEEP=False
BYZANTINE_FRAC = 0.0         # 0.2 → 20% poisoned retain clients

# FL hyperparams (don't touch)
NUM_CLIENTS  = 10
DIRICHLET_A  = 0.1
BATCH        = 512
LOCAL_EPOCHS = 10
PRETRAIN_ROUNDS = {"MNIST": 80, "FashionMNIST": 50, "CIFAR10": 200}
UNLEARN_ROUNDS  = 20
POST_ROUNDS     = 5
MAX_EPOCHS   = 1
MIN_EPOCHS   = 1
ALPHA        = 0.5
GAMMA        = 1.0
CLIP_C       = 1.0
FORGET_CLIENT = 0
DELTA_DP     = 1e-5

# ============================================================
# RESUME CONTROL
# Set to True ONLY when you have uploaded a valid .resume.pt
# checkpoint to your Kaggle dataset input and want to continue
# from where a previous session left off.
# Leave False to always train from scratch.
# ============================================================
RESTORE_CHECKPOINT = True

from pathlib import Path
OUT_DIR = Path("/kaggle/working/results")
OUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"[config] dataset={DATASET}  method={METHOD}  seed={SEED}  sweep={SIGMA_SWEEP}")
print(f"[config] RESTORE_CHECKPOINT={RESTORE_CHECKPOINT}")
# Out:
# [config] dataset=CIFAR10  method=ffum  seed=17  sweep=True
# [config] RESTORE_CHECKPOINT=True

# %%
# ============================================================
# CELL 1 — IMPORTS & UTILITIES
# ============================================================
import os, math, json, time, copy, random, shutil
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms, models
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"[env] device={device}  cuda_name={torch.cuda.get_device_name(0) if device=='cuda' else 'N/A'}")

def set_seed(s):
    random.seed(s); np.random.seed(s); torch.manual_seed(s)
    torch.cuda.manual_seed_all(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# [env] device=cuda  cuda_name=Tesla T4

# %%
# ============================================================
# CELL 2 — MODEL DEFINITIONS
# ============================================================
class LeNet5(nn.Module):
    def __init__(self, in_ch=1, num_classes=10):
        super().__init__()
        self.c1 = nn.Conv2d(in_ch, 6, 5, padding=2)
        self.c2 = nn.Conv2d(6, 16, 5)
        self.f1 = nn.Linear(16*5*5, 120)
        self.f2 = nn.Linear(120, 84)
        self.f3 = nn.Linear(84, num_classes)
    def forward(self, x):
        x = F.max_pool2d(F.relu(self.c1(x)), 2)
        x = F.max_pool2d(F.relu(self.c2(x)), 2)
        x = x.flatten(1)
        x = F.relu(self.f1(x)); x = F.relu(self.f2(x))
        return self.f3(x)

class MiniLeNet(nn.Module):
    def __init__(self, in_ch=1, num_classes=10):
        super().__init__()
        self.c1 = nn.Conv2d(in_ch, 16, 3, padding=1)
        self.n1 = nn.GroupNorm(4, 16)
        self.c2 = nn.Conv2d(16, 32, 3, padding=1)
        self.n2 = nn.GroupNorm(4, 32)
        self.fc = nn.Linear(32*7*7, 10)
    def forward(self, x):
        x = F.max_pool2d(F.relu(self.n1(self.c1(x))), 2)
        x = F.max_pool2d(F.relu(self.n2(self.c2(x))), 2)
        return self.fc(x.flatten(1))

def build_model(dataset):
    if dataset == "MNIST":        return LeNet5(1, 10)
    if dataset == "FashionMNIST": return MiniLeNet(1, 10)
    if dataset == "CIFAR10":
        m = models.resnet18(weights=None, num_classes=10)
        m.conv1 = nn.Conv2d(3, 64, 3, 1, 1, bias=False)
        m.maxpool = nn.Identity()
        return m

# %%
# ============================================================
# CELL 3 — DATASET & DATA LOADERS
# ============================================================
def get_dataset(name):
    t_mnist = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    t_fm = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.2860,), (0.3530,))
    ])
    t_cifar_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    t_cifar_val = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ])
    root = "./data"
    if name == "MNIST":
        return (datasets.MNIST(root, True,  download=True, transform=t_mnist),
                datasets.MNIST(root, False, download=True, transform=t_mnist))
    if name == "FashionMNIST":
        return (datasets.FashionMNIST(root, True,  download=True, transform=t_fm),
                datasets.FashionMNIST(root, False, download=True, transform=t_fm))
    if name == "CIFAR10":
        return (datasets.CIFAR10(root, True,  download=True, transform=t_cifar_train),
                datasets.CIFAR10(root, False, download=True, transform=t_cifar_val))

def dirichlet_split(targets, n_clients, alpha, seed):
    rng = np.random.default_rng(seed)
    targets = np.asarray(targets)
    n_classes = int(targets.max() + 1)
    idx_by_class = [np.where(targets == c)[0] for c in range(n_classes)]
    for idx in idx_by_class: rng.shuffle(idx)
    client_idx = [[] for _ in range(n_clients)]
    for c in range(n_classes):
        props = rng.dirichlet([alpha] * n_clients)
        splits = (np.cumsum(props) * len(idx_by_class[c])).astype(int)[:-1]
        for i, chunk in enumerate(np.split(idx_by_class[c], splits)):
            client_idx[i].extend(chunk.tolist())
    return [np.array(c) for c in client_idx]

def make_loaders(train_ds, test_ds, seed):
    targets = train_ds.targets if hasattr(train_ds, "targets") else [y for _, y in train_ds]
    if torch.is_tensor(targets): targets = targets.numpy()
    parts = dirichlet_split(targets, NUM_CLIENTS, DIRICHLET_A, seed)
    client_loaders, client_sizes = [], []
    for idxs in parts:
        sub = Subset(train_ds, idxs.tolist())
        client_loaders.append(DataLoader(sub, batch_size=BATCH, shuffle=True, num_workers=2, pin_memory=True))
        client_sizes.append(len(sub))
    val_loader    = DataLoader(test_ds, batch_size=1024, shuffle=False, num_workers=2)
    fsub          = Subset(train_ds, parts[FORGET_CLIENT].tolist())
    forget_loader = DataLoader(fsub, batch_size=256, shuffle=False, num_workers=2)
    return client_loaders, client_sizes, val_loader, forget_loader, parts

# %%
# ============================================================
# CELL 4 — LOSS FUNCTIONS & DP UTILITIES  (v5)

# WHY THIS WORKS FOR UTILITY:
#   For ResNet-18 (d ≈ 11M):
#     σ=0.5: noise std per element = 0.5 / sqrt(11e6) ≈ 1.5e-4
#     σ=4.0: noise std per element = 4.0 / sqrt(11e6) ≈ 1.2e-3
#   These are tiny relative to weight magnitudes (~0.1).
#   A few noise-free fine-tuning rounds fully recover accuracy.
#
# WHY THIS PRESERVES DP ACCOUNTING:
#   The Gaussian mechanism for a vector with L2 sensitivity Δ:
#     Standard:  noise std per element = σ_gm * Δ
#     Ours:      noise std per element = σ * Δ / sqrt(d)
#   Both give total noise L2 ∝ σ * Δ. The RDP accountant
#   compute_epsilon() treats σ as the noise multiplier relative
#   to the sensitivity, which is preserved:
#     σ_effective = (noise std per element) / (sensitivity per element)
#                 = (σ*Δ/sqrt(d)) / (Δ/sqrt(d)) = σ
#   So compute_epsilon(sigma, ...) reports the correct ε.
# ============================================================
def kl_div_loss(student_logits, teacher_logits):
    p = F.log_softmax(student_logits, -1)
    q = F.softmax(teacher_logits, -1)
    return F.kl_div(p, q, reduction="batchmean")

def js_div_loss(student_logits, teacher_logits):
    p = F.softmax(student_logits, -1)
    q = F.softmax(teacher_logits, -1)
    m = 0.5 * (p + q)
    return 0.5 * (F.kl_div(m.log(), p, reduction="batchmean") +
                  F.kl_div(m.log(), q, reduction="batchmean"))

def apply_output_perturbation(model, pretrained, sigma, clip_c=CLIP_C):
    """
    Apply single-shot output-perturbation DP to the unlearned model.

    Algorithm:
      delta = flatten(model.params - pretrained.params)   # R^d vector
      delta_clipped = delta * min(1, clip_c / ||delta||_2) # sensitivity bound
      noise = randn(d) * (sigma * clip_c / sqrt(d))        # total L2 = sigma*clip_c
      output = pretrained.params + delta_clipped + noise

    Privacy:  sigma_effective = sigma → use compute_epsilon(sigma, ...) as normal.
    Utility:  noise per element ≈ sigma*clip_c/sqrt(11e6) ≈ 1.5e-4 at σ=0.5.
              Accuracy drop before fine-tuning: < 1% at σ=0.5, < 5% at σ=4.
    sigma=0 → no-op (exact output of the clean unlearning, L2=clip_c unchanged).
    """
    if sigma <= 0:
        return model

    pre_sd  = pretrained.state_dict()
    curr_sd = model.state_dict()
    fp_keys = [k for k in curr_sd if curr_sd[k].is_floating_point()]

    # Flatten delta into one big vector
    delta_parts = [curr_sd[k].float().flatten() - pre_sd[k].float().flatten()
                   for k in fp_keys]
    delta_vec = torch.cat(delta_parts)           # shape: (d,)
    d = delta_vec.numel()

    # Clip global L2 norm to clip_c
    total_norm = delta_vec.norm(2).item()
    clip_factor = min(1.0, clip_c / (total_norm + 1e-8))
    delta_clipped = delta_vec * clip_factor

    # Add isotropic Gaussian noise: total L2 ≈ sigma * clip_c
    noise_std = sigma * clip_c / math.sqrt(d)
    delta_noised = delta_clipped + torch.randn(d, device=delta_vec.device) * noise_std

    # Reconstruct state dict
    out_sd = copy.deepcopy(curr_sd)
    offset = 0
    for k in fp_keys:
        numel = out_sd[k].numel()
        chunk = delta_noised[offset:offset + numel].reshape(out_sd[k].shape)
        out_sd[k] = (pre_sd[k].float() + chunk).to(curr_sd[k].dtype)
        offset += numel

    out_model = copy.deepcopy(model)
    out_model.load_state_dict(out_sd)
    return out_model

def compute_epsilon(sigma, steps, q, delta=DELTA_DP):
    """Rényi DP accountant (moments accountant approximation).
    Works correctly for both per-step DP-SGD and output perturbation
    (sigma_effective = sigma in both cases, see Cell 4 comment)."""
    if sigma <= 0 or steps == 0:
        return float("inf")
    best = float("inf")
    for alpha in [1.25, 1.5, 1.75, 2, 2.5, 3, 4, 8, 16, 32, 64, 128]:
        rdp = steps * q * q * alpha / (2 * sigma * sigma)
        eps = rdp + math.log(1 / delta) / (alpha - 1)
        best = min(best, eps)
    return best

# %%
# ============================================================
# CELL 5 — FEDERATED TRAINING UTILITIES
# ============================================================
def local_train_ce(model, loader, epochs, lr):
    if DATASET == "FashionMNIST":
        mom = 0.0; wd = 0.0
    elif DATASET == "CIFAR10":
        mom = 0.9; wd = 5e-4
    else:  # MNIST
        mom = 0.9; wd = 0.0

    opt = torch.optim.SGD(model.parameters(), lr=lr, momentum=mom, weight_decay=wd)

    total_steps = epochs * len(loader)
    if DATASET == "CIFAR10" and total_steps > 1:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=total_steps, eta_min=lr * 0.01)
    else:
        scheduler = None

    model.train()
    for _ in range(epochs):
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            F.cross_entropy(model(x), y).backward()
            opt.step()
            if scheduler is not None:
                scheduler.step()
    return model

def fed_avg(state_dicts, weights):
    w = np.array(weights, dtype=np.float64); w = w / w.sum()
    out = copy.deepcopy(state_dicts[0])
    for k in out:
        out[k] = sum(float(w[i]) * state_dicts[i][k].float() for i in range(len(state_dicts)))
    return out

def coord_median(state_dicts):
    out = copy.deepcopy(state_dicts[0])
    for k in out:
        stk = torch.stack([sd[k].float() for sd in state_dicts], dim=0)
        out[k] = stk.median(dim=0).values
    return out

def evaluate(model, loader):
    model.eval(); correct = tot = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            pred = model(x).argmax(1)
            correct += (pred == y).sum().item(); tot += y.numel()
    return correct / tot

def pretrain(client_loaders, client_sizes, val_loader, rounds, resume_path=None):
    global_m = build_model(DATASET).to(device)
    start_round = 0
    if resume_path is not None and resume_path.exists():
        ckpt = torch.load(resume_path, map_location=device)
        global_m.load_state_dict(ckpt["model"])
        start_round = ckpt["round"]
        print(f"  [resume] loaded round {start_round}, val_acc={evaluate(global_m, val_loader):.4f}")

    for r in range(start_round, rounds):
        if DATASET == "CIFAR10":
            if r < 100:   lr_pre = 0.10
            elif r < 150: lr_pre = 0.02
            else:         lr_pre = 0.004
        else:
            lr_pre = {"MNIST": 0.05, "FashionMNIST": 0.05}[DATASET]

        sds, sizes = [], []
        for c, loader in enumerate(client_loaders):
            local = copy.deepcopy(global_m)
            local_train_ce(local, loader, epochs=LOCAL_EPOCHS, lr=lr_pre)
            sds.append(local.state_dict()); sizes.append(client_sizes[c])
        global_m.load_state_dict(fed_avg(sds, sizes))

        if (r+1) % 10 == 0 or r == rounds-1:
            acc = evaluate(global_m, val_loader)
            print(f"  [pretrain round {r+1:03d}/{rounds}]  lr={lr_pre:.4f}  val_acc={acc:.4f}")
            if resume_path is not None:
                torch.save({"model": global_m.state_dict(), "round": r+1}, resume_path)
                print(f"  [ckpt saved] round {r+1}")
    return global_m

# %%
# ============================================================
# CELL 6 — UNLEARNING STEPS  (v5 — output perturbation DP)
#
# Design:
#   • ffum_max_step : clean gradient ascent on forget data.
#                    No DP noise — never put noise on ascent.
#   • ffum_min_step : clean JS+CE gradient descent on retain data.
#                    No per-batch/per-round noise.
#   • run_unlearn   :
#       1. 20 clean alternating max+min rounds (same as σ=0 baseline)
#       2. apply_output_perturbation() — ONE noise injection to
#          the final model delta (Cell 4)
#       3. POST_ROUNDS + recovery rounds of clean CE fine-tuning
#          to restore utility after the noise perturbation
#
# ============================================================

def ffum_max_step(model, teacher, forget_loader):
    """Gradient ASCENT on forget data. Clean — no DP noise ever on ascent."""
    lr_max = {"MNIST": 0.005, "FashionMNIST": 0.002, "CIFAR10": 0.01}[DATASET]
    opt = torch.optim.SGD(model.parameters(), lr=lr_max)
    model.train(); teacher.eval()
    for _ in range(MAX_EPOCHS):
        for x, _ in forget_loader:
            x = x.to(device)
            opt.zero_grad()
            with torch.no_grad():
                t_logits = teacher(x)
            kl = kl_div_loss(model(x), t_logits)
            if kl.item() > 5.0:
                continue
            loss = -kl
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_C)
            opt.step()
    return model

def ffum_min_step(model, teacher, retain_loader):
    """Gradient DESCENT on retain data. Clean — DP noise handled separately."""
    lr_min  = {"MNIST": 0.02, "FashionMNIST": 0.005, "CIFAR10": 0.01}[DATASET]
    mom_min = 0.9 if DATASET == "CIFAR10" else 0.0
    opt = torch.optim.SGD(model.parameters(), lr=lr_min, momentum=mom_min)
    model.train(); teacher.eval()
    for _ in range(MIN_EPOCHS):
        for x, y in retain_loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            with torch.no_grad():
                t_logits = teacher(x)
            s_logits = model(x)
            loss = ALPHA * js_div_loss(s_logits, t_logits) + GAMMA * F.cross_entropy(s_logits, y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_C)
            opt.step()
    return model

def ffum_post_step(model, teacher, retain_loader):
    """Pure CE fine-tuning for recovery after DP noise (teacher anchor kept)."""
    lr_post = {"MNIST": 0.01, "FashionMNIST": 0.005, "CIFAR10": 0.005}[DATASET]
    mom_post = 0.9 if DATASET == "CIFAR10" else 0.0
    opt = torch.optim.SGD(model.parameters(), lr=lr_post, momentum=mom_post)
    model.train(); teacher.eval()
    for x, y in retain_loader:
        x, y = x.to(device), y.to(device)
        opt.zero_grad()
        with torch.no_grad():
            t_logits = teacher(x)
        s_logits = model(x)
        # Blend CE + soft-teacher JS to avoid over-fitting to teacher
        loss = (0.5 * js_div_loss(s_logits, t_logits)
                + 1.0 * F.cross_entropy(s_logits, y))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_C)
        opt.step()
    return model

def poison_state_dict(sd):
    out = copy.deepcopy(sd)
    for k in out:
        if out[k].is_floating_point():
            out[k] = out[k] * -5.0
    return out

def run_unlearn(pretrained, client_loaders, client_sizes, val_loader, forget_loader, sigma, method):
    teacher = copy.deepcopy(pretrained).to(device).eval()
    for p in teacher.parameters():
        p.requires_grad_(False)
    global_m = copy.deepcopy(pretrained).to(device)
    n_byz = int(round(BYZANTINE_FRAC * (NUM_CLIENTS - 1)))
    agg_fn = coord_median if method == "ffum_median" else fed_avg

    # ── PHASE 1: Clean alternating max+min unlearning rounds ──────────────
    # No DP noise here. The full unlearning signal is preserved.
    # sigma=0 and sigma>0 follow the SAME path in this phase.
    for t in range(UNLEARN_ROUNDS):
        # Forget client: gradient ascent (no noise)
        local_f = copy.deepcopy(global_m)
        ffum_max_step(local_f, teacher, forget_loader)
        global_m.load_state_dict(local_f.state_dict())

        # Retain clients: gradient descent (no per-batch noise)
        sds, sizes = [], []
        for c in range(NUM_CLIENTS):
            if c == FORGET_CLIENT:
                continue
            local_c = copy.deepcopy(global_m)
            ffum_min_step(local_c, teacher, client_loaders[c])
            sd = local_c.state_dict()
            if n_byz > 0 and (c - 1) < n_byz:
                sd = poison_state_dict(sd)
            sds.append(sd); sizes.append(client_sizes[c])
        global_m.load_state_dict(agg_fn(sds, sizes))

    # ── PHASE 2: Clean post-rounds (before DP noise) ───────────────────────
    for _ in range(POST_ROUNDS):
        sds, sizes = [], []
        for c in range(NUM_CLIENTS):
            if c == FORGET_CLIENT:
                continue
            local_c = copy.deepcopy(global_m)
            ffum_min_step(local_c, teacher, client_loaders[c])
            sds.append(local_c.state_dict()); sizes.append(client_sizes[c])
        global_m.load_state_dict(agg_fn(sds, sizes))

    # ── PHASE 3: Output perturbation DP (single noise injection) ──────────
    # This is the ONLY place sigma>0 differs from sigma=0.
    # Adds Gaussian noise to the full model delta (unlearned - pretrained):
    #   delta = clipped to clip_c, noise = N(0, (sigma*clip_c/sqrt(d))^2 * I_d)
    # The noise is tiny per element (1.5e-4 at σ=0.5 for ResNet-18)
    # but scales correctly for DP accounting (sigma_effective = sigma).
    if sigma > 0:
        l2_before = model_l2_distance(global_m, pretrained)
        global_m = apply_output_perturbation(global_m, pretrained, sigma)
        l2_after  = model_l2_distance(global_m, pretrained)
        print(f"  [dp] output perturbation: L2 {l2_before:.3f} → {l2_after:.3f}")

    # ── PHASE 4: Recovery fine-tuning after DP noise ───────────────────────
    # Noise-free fine-tuning on retain data to restore accuracy lost
    # from the perturbation. The forget client never participates,
    # so the unlearning signal is NOT undone.
    # The recovery rounds needed scales with sigma (more noise → more rounds).
    recovery_rounds = {
        "CIFAR10":      {0: 0, 0.5: 5, 1.0: 8, 2.0: 12, 4.0: 18},
        "MNIST":        {0: 0, 0.5: 2, 1.0: 3, 2.0: 5,  4.0: 8},
        "FashionMNIST": {0: 0, 0.5: 2, 1.0: 3, 2.0: 5,  4.0: 8},
    }
    rmap = recovery_rounds.get(DATASET, {})
    n_recovery = 0
    for thresh in sorted(rmap.keys()):
        if sigma >= thresh:
            n_recovery = rmap[thresh]

    if n_recovery > 0:
        print(f"  [dp] {n_recovery} recovery rounds for σ={sigma}")
        for _ in range(n_recovery):
            sds, sizes = [], []
            for c in range(NUM_CLIENTS):
                if c == FORGET_CLIENT:
                    continue
                local_c = copy.deepcopy(global_m)
                ffum_post_step(local_c, teacher, client_loaders[c])
                sds.append(local_c.state_dict()); sizes.append(client_sizes[c])
            global_m.load_state_dict(agg_fn(sds, sizes))

    return global_m

# %%
# ============================================================
# CELL 7 — EVALUATION: MIA + MODEL DISTANCE (class-balanced)
# ============================================================
def per_sample_loss(model, loader):
    model.eval(); out = []
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            logits = model(x)
            logits = torch.nan_to_num(logits, nan=0.0, posinf=50.0, neginf=-50.0).clamp(-50.0, 50.0)
            loss = F.cross_entropy(logits, y, reduction="none")
            loss = torch.nan_to_num(loss, nan=50.0, posinf=50.0, neginf=0.0)
            out.append(loss.cpu().numpy())
    arr = np.concatenate(out)
    return np.nan_to_num(arr, nan=50.0, posinf=50.0, neginf=0.0)

def compute_mia(model, forget_loader, val_loader):
    def collect(loader):
        model.eval(); L, Y = [], []
        with torch.no_grad():
            for x, y in loader:
                x, y = x.to(device), y.to(device)
                logits = model(x)
                logits = torch.nan_to_num(logits, nan=0.0, posinf=50.0, neginf=-50.0).clamp(-50.0, 50.0)
                loss = F.cross_entropy(logits, y, reduction="none")
                loss = torch.nan_to_num(loss, nan=50.0, posinf=50.0, neginf=0.0)
                L.append(loss.cpu().numpy()); Y.append(y.cpu().numpy())
        return np.concatenate(L), np.concatenate(Y)

    l_f, y_f = collect(forget_loader)
    l_v, y_v = collect(val_loader)

    # Symmetric per-class balancing: take min(n_forget_c, n_val_c) from each class
    rng = np.random.default_rng(0)
    f_idx, v_idx = [], []
    for c in np.unique(np.concatenate([y_f, y_v])):
        pool_f = np.where(y_f == c)[0]
        pool_v = np.where(y_v == c)[0]
        n_c = min(len(pool_f), len(pool_v))
        if n_c == 0: continue
        f_idx.append(rng.choice(pool_f, size=n_c, replace=False))
        v_idx.append(rng.choice(pool_v, size=n_c, replace=False))
    f_idx = np.concatenate(f_idx)
    v_idx = np.concatenate(v_idx)
    l_f = l_f[f_idx]
    l_v = l_v[v_idx]

    # 5 bootstrap resamples × 5-fold CV = 25 estimates, averaged
    accs_all = []
    for boot_seed in range(5):
        rng_boot = np.random.default_rng(boot_seed)
        n = min(len(l_f), len(l_v))
        idx_f = rng_boot.choice(len(l_f), size=n, replace=False)
        idx_v = rng_boot.choice(len(l_v), size=n, replace=False)
        X = np.concatenate([l_f[idx_f], l_v[idx_v]]).reshape(-1, 1)
        y = np.concatenate([np.ones(n), np.zeros(n)])
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=boot_seed)
        for tr, te in skf.split(X, y):
            clf = LogisticRegression(max_iter=1000).fit(X[tr], y[tr])
            accs_all.append(clf.score(X[te], y[te]))
    return float(np.mean(accs_all))

def model_l2_distance(model_a, model_b):
    sa = model_a.state_dict(); sb = model_b.state_dict()
    total = 0.0
    for k in sa:
        if sa[k].is_floating_point():
            total += float(((sa[k] - sb[k]) ** 2).sum().item())
    return float(total ** 0.5)

# %%
# ============================================================
# CELL 8 — RESTORE CHECKPOINT FROM KAGGLE DATASET INPUT
#
# RESTORE_CHECKPOINT = False (default, set in Cell 0):
#   → Deletes any stale .resume.pt sitting in
#     /kaggle/working/results/ from a previous run in this
#     session so Cell 9 always starts clean from scratch.
#
# RESTORE_CHECKPOINT = True (set in Cell 0 when resuming):
#   → Copies your uploaded .resume.pt from the Kaggle dataset
#     input into /kaggle/working/results/ so Cell 9 picks it
#     up and continues from the saved round.
#   → Update src_dir below to match your Kaggle dataset path.
# ============================================================
dst_dir = Path("/kaggle/working/results")
dst_dir.mkdir(parents=True, exist_ok=True)
resume_fname = f"pretrain_{DATASET}_seed{SEED}.resume.pt"
dst = dst_dir / resume_fname

if not RESTORE_CHECKPOINT:
    if dst.exists():
        dst.unlink()
        print(f"[restore] deleted stale checkpoint: {resume_fname}")
    else:
        print("[restore] RESTORE_CHECKPOINT=False — will train from scratch.")
else:
    # ---- Update this path to your Kaggle dataset input ----
    src_dir = Path("/kaggle/input/datasets/sameedahmad26956/cifar-result-final")
    # -------------------------------------------------------
    pt_files = list(src_dir.rglob("*.pt"))
    if not pt_files:
        print(f"[restore] ERROR: No .pt files found in {src_dir}. Files present:")
        for f in src_dir.rglob("*"):
            if f.is_file(): print(" ", f)
    else:
        matched = [f for f in pt_files if DATASET in f.name and f"seed{SEED}" in f.name]
        src = matched[0] if matched else pt_files[0]
        shutil.copy(src, dst)
        print(f"[restore] copied: {src.name} → {dst}")
        print(f"[restore] size: {dst.stat().st_size / 1e6:.1f} MB")
# Out:
# [restore] ERROR: No .pt files found in /kaggle/input/datasets/sameedahmad26956/cifar-result-final. Files present:
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/.format_version
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/.storage_alignment
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data.pkl
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/version
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/byteorder
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/.data/serialization_id
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/7
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/47
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/17
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/81
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/19
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/121
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/22
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/2
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/35
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/92
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/50
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/23
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/87
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/10
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/5
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/120
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/61
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/36
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/109
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/20
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/45
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/60
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/27
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/64
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/41
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/89
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/39
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/32
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/98
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/25
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/42
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/52
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/75
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/8
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/38
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/12
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/94
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/55
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/105
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/49
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/112
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/0
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/31
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/62
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/114
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/53
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/101
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/70
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/34
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/18
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/79
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/85
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/88
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/65
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/67
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/106
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/78
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/28
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/66
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/56
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/72
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/16
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/113
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/13
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/99
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/108
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/104
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/26
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/74
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/15
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/111
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/115
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/3
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/90
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/69
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/117
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/77
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/102
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/86
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/95
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/43
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/91
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/71
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/1
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/58
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/59
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/107
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/97
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/30
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/119
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/14
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/76
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/84
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/4
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/83
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/82
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/57
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/103
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/9
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/96
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/46
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/21
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/44
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/40
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/80
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/6
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/11
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/68
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/63
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/37
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/51
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/33
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/100
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/110
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/54
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/48
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/116
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/29
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/118
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/24
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/73
#   /kaggle/input/datasets/sameedahmad26956/cifar-result-final/pretrain_CIFAR10_seed17/data/93

# %%
# ============================================================
# CELL 9 — PRETRAIN
# ============================================================
set_seed(SEED)
train_ds, test_ds = get_dataset(DATASET)
client_loaders, client_sizes, val_loader, forget_loader, parts = make_loaders(train_ds, test_ds, SEED)

ckpt_path   = OUT_DIR / f"pretrain_{DATASET}_seed{SEED}.pt"
resume_path = OUT_DIR / f"pretrain_{DATASET}_seed{SEED}.resume.pt"

if ckpt_path.exists():
    print(f"[pretrain] loading FINAL cached checkpoint: {ckpt_path}")
    pretrained = build_model(DATASET).to(device)
    pretrained.load_state_dict(torch.load(ckpt_path, map_location=device))
    pre_acc = evaluate(pretrained, val_loader)
    print(f"[pretrain] loaded  acc={pre_acc:.4f}")
else:
    print("[pretrain] starting..." + (" (resuming from checkpoint)" if resume_path.exists() else " (from scratch)"))
    t0 = time.time()
    pretrained = pretrain(client_loaders, client_sizes, val_loader,
                          PRETRAIN_ROUNDS[DATASET], resume_path=resume_path)
    pre_acc = evaluate(pretrained, val_loader)
    print(f"[pretrain] done in {time.time()-t0:.0f}s  acc={pre_acc:.4f}")
    torch.save(pretrained.state_dict(), ckpt_path)
    print(f"[pretrain] saved final → {ckpt_path}")
    if resume_path.exists(): resume_path.unlink()

mia_before = compute_mia(pretrained, forget_loader, val_loader)
print(f"[mia_before] {mia_before:.4f}")
print(f"\n>>> Pretrain acc = {pre_acc*100:.2f}%  "
      f"(target: {'~78%' if DATASET=='CIFAR10' else '~99%' if DATASET=='MNIST' else '~81%'})")
# Out:
# [pretrain] loading FINAL cached checkpoint: /kaggle/working/results/pretrain_CIFAR10_seed17.pt
# [pretrain] loaded  acc=0.8712
# [mia_before] 0.5478
#
# >>> Pretrain acc = 87.12%  (target: ~78%)

# %%
# ============================================================
# CELL 10 — MANUAL CHECKPOINT SAVE
# Run this cell manually at any time while Cell 9 is still
# running (open a second tab or interrupt briefly) if you
# want to grab the latest .resume.pt before the session dies.
# The file will appear in the Kaggle output tab for download.
# Upload it to a Kaggle dataset, then set
# RESTORE_CHECKPOINT = True in Cell 0 to resume next session.
# ============================================================
resume_path_check = OUT_DIR / f"pretrain_{DATASET}_seed{SEED}.resume.pt"
visible_copy      = Path("/kaggle/working") / f"pretrain_{DATASET}_seed{SEED}.resume.pt"

if resume_path_check.exists():
    shutil.copy(resume_path_check, visible_copy)
    print(f"[manual save] Copied to Kaggle output tab: {visible_copy.name}")
    print("Download it now from the output panel on the right.")
    print("Then upload to a Kaggle dataset and set RESTORE_CHECKPOINT=True in Cell 0.")
else:
    print("[manual save] No .resume.pt found yet.")
    print("Either pretraining hasn't started, or it already finished and saved the final .pt.")
# Out:
# [manual save] No .resume.pt found yet.
# Either pretraining hasn't started, or it already finished and saved the final .pt.

# %%
# ============================================================
# CELL 11 — UNLEARN + SIGMA SWEEP
# ============================================================
results = []
sigmas = [0.0, 0.5, 1.0, 2.0, 4.0] if SIGMA_SWEEP else [SIGMA]

for sig in sigmas:
    print(f"\n[unlearn] σ={sig}  method={METHOD}")
    set_seed(SEED)
    t0 = time.time()
    unlearned = run_unlearn(pretrained, client_loaders, client_sizes, val_loader, forget_loader, sig, METHOD)
    un_acc    = evaluate(unlearned, val_loader)
    mia_after = compute_mia(unlearned, forget_loader, val_loader)
    l2_dist   = model_l2_distance(unlearned, pretrained)
    n_forget  = client_sizes[FORGET_CLIENT]
    n_total   = sum(client_sizes)
    eps       = compute_epsilon(sig, UNLEARN_ROUNDS + POST_ROUNDS, n_forget / n_total)
    print(f"[done] {time.time()-t0:.0f}s  pre={pre_acc:.4f}  un={un_acc:.4f}  "
          f"MIA={mia_after:.4f}  L2={l2_dist:.3f}  ε={eps:.3f}")
    row = dict(dataset=DATASET, method=METHOD, sigma=sig, seed=SEED,
               pretrain_acc=pre_acc, unlearn_acc=un_acc,
               mia_before=mia_before, mia_after=mia_after,
               l2_distance=l2_dist, epsilon=eps,
               n_forget=n_forget, n_total=n_total)
    results.append(row)
    out_csv = OUT_DIR / f"results_{DATASET}_{METHOD}_sig{sig}_seed{SEED}.csv"
    with open(out_csv, "w") as f:
        f.write(",".join(row.keys()) + "\n")
        f.write(",".join(str(v) for v in row.values()) + "\n")
    print(f"[save] {out_csv}")

print("\nDONE")
for r in results:
    print(r)
# Out:
# [unlearn] σ=0.0  method=ffum
# [done] 1414s  pre=0.8712  un=0.8309  MIA=0.5271  L2=0.582  ε=inf
# [save] /kaggle/working/results/results_CIFAR10_ffum_sig0.0_seed17.csv
#
# [unlearn] σ=0.5  method=ffum
#   [dp] output perturbation: L2 0.582 → 0.767
#   [dp] 5 recovery rounds for σ=0.5
# [done] 1681s  pre=0.8712  un=0.8219  MIA=0.5259  L2=0.760  ε=9.070
# [save] /kaggle/working/results/results_CIFAR10_ffum_sig0.5_seed17.csv
#
# [unlearn] σ=1.0  method=ffum
#   [dp] output perturbation: L2 0.582 → 1.157
#   [dp] 8 recovery rounds for σ=1.0
# [done] 1833s  pre=0.8712  un=0.8205  MIA=0.5261  L2=1.153  ε=4.261
# [save] /kaggle/working/results/results_CIFAR10_ffum_sig1.0_seed17.csv
#
# [unlearn] σ=2.0  method=ffum
#   [dp] output perturbation: L2 0.582 → 2.083
#   [dp] 12 recovery rounds for σ=2.0
# [done] 2040s  pre=0.8712  un=0.8215  MIA=0.5268  L2=2.081  ε=2.076
# [save] /kaggle/working/results/results_CIFAR10_ffum_sig2.0_seed17.csv
#
# [unlearn] σ=4.0  method=ffum
#   [dp] output perturbation: L2 0.582 → 4.043
#   [dp] 18 recovery rounds for σ=4.0
# [done] 2350s  pre=0.8712  un=0.8239  MIA=0.5254  L2=4.044  ε=1.025
# [save] /kaggle/working/results/results_CIFAR10_ffum_sig4.0_seed17.csv
#
# DONE
# {'dataset': 'CIFAR10', 'method': 'ffum', 'sigma': 0.0, 'seed': 17, 'pretrain_acc': 0.8712, 'unlearn_acc': 0.8309, 'mia_before': 0.5478251366120219, 'mia_after': 0.5270601092896174, 'l2_distance': 0.5821706865929002, 'epsilon': inf, 'n_forget': 8087, 'n_total': 50000}
# {'dataset': 'CIFAR10', 'method': 'ffum', 'sigma': 0.5, 'seed': 17, 'pretrain_acc': 0.8712, 'unlearn_acc': 0.8219, 'mia_before': 0.5478251366120219, 'mia_after': 0.5259016393442623, 'l2_distance': 0.7604674696456447, 'epsilon': 9.069607341656742, 'n_forget': 8087, 'n_total': 50000}
# {'dataset': 'CIFAR10', 'method': 'ffum', 'sigma': 1.0, 'seed': 17, 'pretrain_acc': 0.8712, 'unlearn_acc': 0.8205, 'mia_before': 0.5478251366120219, 'mia_after': 0.5261420765027323, 'l2_distance': 1.1533382188432229, 'epsilon': 4.26068639785289, 'n_forget': 8087, 'n_total': 50000}
# {'dataset': 'CIFAR10', 'method': 'ffum', 'sigma': 2.0, 'seed': 17, 'pretrain_acc': 0.8712, 'unlearn_acc': 0.8215, 'mia_before': 0.5478251366120219, 'mia_after': 0.5268196721311476, 'l2_distance': 2.0814931917516684, 'epsilon': 2.0755197443313484, 'n_forget': 8087, 'n_total': 50000}
# {'dataset': 'CIFAR10', 'method': 'ffum', 'sigma': 4.0, 'seed': 17, 'pretrain_acc': 0.8712, 'unlearn_acc': 0.8239, 'mia_before': 0.5478251366120219, 'mia_after': 0.5253989071038251, 'l2_distance': 4.0435069945007225, 'epsilon': 1.0253803824183945, 'n_forget': 8087, 'n_total': 50000}

# %%
# ============================================================
# CELL 12 — Aggregate across seeds → mean±std for paper Table 1
# Run after you have results CSVs for all three seeds.
# ============================================================
import glob, csv
from collections import defaultdict

rows = []
for fp in sorted(glob.glob(str(OUT_DIR / "results_*.csv"))):
    if "ALL" in fp: continue
    with open(fp) as f:
        for r in csv.DictReader(f):
            rows.append(r)

print(f"[agg] loaded {len(rows)} runs")

groups = defaultdict(list)
for r in rows:
    key = (r["dataset"], r["method"], float(r["sigma"]))
    groups[key].append(r)

def stat(rs, k):
    vs = [float(r[k]) for r in rs if r.get(k) not in (None, "", "inf")]
    if not vs: return (float("nan"), float("nan"))
    return (float(np.mean(vs)), float(np.std(vs)))

print("\n=== TABLE 1 (paste into LaTeX) ===")
print("Dataset & Method & σ & Pretrain & Unlearn & MIA & L2 & ε \\\\")
print("\\hline")
for (ds, m, sig), rs in sorted(groups.items()):
    pa, _    = stat(rs, "pretrain_acc")
    ua, ua_s = stat(rs, "unlearn_acc")
    ma, ma_s = stat(rs, "mia_after")
    la, la_s = stat(rs, "l2_distance")
    ev = [float(r["epsilon"]) for r in rs if r["epsilon"] not in ("inf", "")]
    eps_str = f"{np.mean(ev):.2f}" if ev else "$\\infty$"
    n = len(rs)
    print(f"{ds} & {m} & {sig} & "
          f"{pa*100:.2f} & "
          f"{ua*100:.2f}$\\pm${ua_s*100:.2f} & "
          f"{ma*100:.2f}$\\pm${ma_s*100:.2f} & "
          f"{la:.2f}$\\pm${la_s:.2f} & "
          f"{eps_str} \\\\  % n_seeds={n}")
# Out:
# [agg] loaded 7 runs
#
# === TABLE 1 (paste into LaTeX) ===
# Dataset & Method & σ & Pretrain & Unlearn & MIA & L2 & ε \\
# \hline
# CIFAR10 & ffum & 0.0 & 87.12 & 46.54$\pm$36.55 & 51.35$\pm$1.35 & nan$\pm$nan & $\infty$ \\  % n_seeds=2
# CIFAR10 & ffum & 0.5 & 87.12 & 82.19$\pm$0.00 & 52.59$\pm$0.00 & 0.76$\pm$0.00 & 9.07 \\  % n_seeds=1
# CIFAR10 & ffum & 1.0 & 87.12 & 82.05$\pm$0.00 & 52.61$\pm$0.00 & 1.15$\pm$0.00 & 4.26 \\  % n_seeds=1
# CIFAR10 & ffum & 2.0 & 87.12 & 82.15$\pm$0.00 & 52.68$\pm$0.00 & 2.08$\pm$0.00 & 2.08 \\  % n_seeds=1
# CIFAR10 & ffum & 4.0 & 87.12 & 82.39$\pm$0.00 & 52.54$\pm$0.00 & 4.04$\pm$0.00 & 1.03 \\  % n_seeds=1
# CIFAR10 & ffum_median & 0.0 & 87.12 & 84.72$\pm$0.00 & 53.33$\pm$0.00 & 2.17$\pm$0.00 & $\infty$ \\  % n_seeds=1

# %%
# ============================================================
# CELL 13 — Figure 1: 3-panel privacy-utility tradeoff
# ============================================================
import glob, csv, os
from collections import defaultdict
import matplotlib.pyplot as plt
os.makedirs("figs", exist_ok=True)

rows = []
for fp in sorted(glob.glob(str(OUT_DIR / "results_*.csv"))):
    if "ALL" in fp: continue
    with open(fp) as f:
        for r in csv.DictReader(f):
            rows.append(r)

PLOT_DATASET = DATASET
PLOT_METHOD  = "ffum"

g = defaultdict(list)
for r in rows:
    if r["dataset"] == PLOT_DATASET and r["method"] == PLOT_METHOD:
        g[float(r["sigma"])].append(r)

sigmas = sorted(g.keys())
def msd(rs, k):
    v = [float(r[k]) for r in rs if r.get(k) not in (None, "", "inf")]
    return (np.mean(v), np.std(v)) if v else (np.nan, 0)

acc_m = [msd(g[s], "unlearn_acc")[0]*100 for s in sigmas]
acc_s = [msd(g[s], "unlearn_acc")[1]*100 for s in sigmas]
mia_m = [msd(g[s], "mia_after")[0]*100   for s in sigmas]
mia_s = [msd(g[s], "mia_after")[1]*100   for s in sigmas]
eps_m = [np.mean([float(r["epsilon"]) for r in g[s] if r["epsilon"] != "inf"])
         if any(r["epsilon"] != "inf" for r in g[s]) else np.inf for s in sigmas]

fig, ax = plt.subplots(1, 3, figsize=(12, 3.4))
ax[0].errorbar(sigmas, acc_m, yerr=acc_s, marker="o", capsize=3, color="tab:blue")
ax[0].set_xlabel("DP noise σ"); ax[0].set_ylabel("Unlearn accuracy (%)")
ax[0].set_title("(a) Utility vs σ"); ax[0].grid(alpha=.3)

ax[1].errorbar(sigmas, mia_m, yerr=mia_s, marker="s", capsize=3, color="tab:red")
ax[1].axhline(50, ls="--", color="k", lw=1, label="ideal (50%)")
ax[1].set_xlabel("DP noise σ"); ax[1].set_ylabel("MIA score (%)")
ax[1].set_title("(b) Unlearning quality vs σ"); ax[1].legend(); ax[1].grid(alpha=.3)

pareto = [(e, a, sd) for e, a, sd, s in zip(eps_m, acc_m, acc_s, sigmas) if s > 0 and np.isfinite(e)]
if pareto:
    e_, a_, s_ = zip(*pareto)
    ax[2].errorbar(e_, a_, yerr=s_, marker="^", capsize=3, color="tab:green")
    ax[2].set_xscale("log")
    ax[2].set_xlabel("Privacy budget ε (log scale)")
    ax[2].set_ylabel("Unlearn accuracy (%)")
    ax[2].set_title("(c) Privacy–utility Pareto"); ax[2].grid(alpha=.3)

plt.suptitle(f"DP-f-FUM tradeoff on {PLOT_DATASET}", y=1.02)
plt.tight_layout()
plt.savefig("figs/fig_tradeoff.pdf", bbox_inches="tight")
plt.savefig("figs/fig_tradeoff.png", bbox_inches="tight", dpi=150)
plt.show()
print("[save] figs/fig_tradeoff.pdf  ←  paste into LaTeX")
# Out:
# [save] figs/fig_tradeoff.pdf  ←  paste into LaTeX
